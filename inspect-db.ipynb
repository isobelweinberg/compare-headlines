# %%
import sqlite3

##Open database
conn = sqlite3.connect('headlines.db')
c = conn.cursor()

##Use to look at index table if needed
for row in c.execute("SELECT * FROM idx"):
    print(row)
# Out:
# (1, 'guardian')
# (2, 'BBCnews')
# (3, 'dailymail')

# %%
for row in c.execute("SELECT * FROM guardian"):
    print(row)
# Out:
# (1, '2018-02-17', '2018-02-17 20:02:46.557325', 'Rightwing groups plot to ditch EU food standards', '')
# (2, '2018-02-17', '2018-02-17 20:02:46.557325', 'Members vote to sack leader Henry Bolton', '')
# (3, '2018-02-17', '2018-02-17 20:02:46.557325', "Putin’s chef, a troll farm and Russia's plot to hijack American democracy", '')
# (4, '2018-02-17', '2018-02-17 20:02:46.557325', 'Lizzy Yarnold takes skeleton gold to make history for Britain', '')
# (5, '2018-02-17', '2018-02-17 20:02:46.557325', 'Tremor hits south-west England and south Wales', '')
# (6, '2018-02-17', '2018-02-17 20:02:46.557325', 'Man and teenage boy killed in level-crossing crash', '')
# (7, '2018-02-17', '2018-02-17 20:02:46.557325', 'Fire on building site is brought under control', '')
# (8, '2018-02-17', '2018-02-17 20:02:46.557325', 'Three suicide bombers kill at least 20 people at market', '')
# (9, '2018-02-17', '2018-02-17 20:02:46.557325', 'Man charged with murder of woman in flat', '')
# ...
